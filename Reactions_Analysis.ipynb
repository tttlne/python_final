# %% [markdown]
# <a href="https://colab.research.google.com/github/tttlne/python_final/blob/master/Reactions_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kết nối drive, thư viện

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Đọc dữ liệu

# %%
df_reactions = pd.read_excel("/content/drive/MyDrive/Colab_Notebooks/napbook.vn_reactions.xlsx")
df_reactions
# Out:
#     Unnamed: 0          post_id  \
# 0            0  415655727456205
# 1            1  415601764128268
# 2            2  415420370813074
# 3            3  415403874148057
# 4            4  415367664151678
# ..         ...              ...
# 95          95  397097782645333
# 96          96  396526536035791
# 97          97  396217742733337
# 98          98  395553969466381
# 99          99  343564324796564
#
#                                             post_text                time  \
# 0   VIDEO: CHỮA ĐỀ THỰC CHIẾN - LẦN 18 [CN - 26/11... 2023-11-27 03:06:06
# 1   [BÀI CHIA SẺ CẢM NHẬN]\nNAPer 2K6: Nguyễn Thị ... 2023-11-27 00:16:07
# 2   🔥 BÁO ĐIỂM VINH DANH 🔥\nKIỂM TRA ĐỊNH KỲ - 2K6... 2023-11-26 15:05:55
# 3   THÔNG BÁO\nDo sự cố mất mạng nên buổi LIVE chữ... 2023-11-26 14:27:45
# 4   🔥 THI THỰC CHIẾN CHUYÊN ĐỀ - 2K6 LỚP 12 - LẦN ... 2023-11-26 13:00:26
# ..                                                ...                 ...
# ...

# %%
# xóa cột thừa Unnamed
df_reactions = df_reactions.drop(columns=[df.columns[0]])
df_reactions
# Out:
#             post_id                                          post_text  \
# 0   415655727456205  VIDEO: CHỮA ĐỀ THỰC CHIẾN - LẦN 18 [CN - 26/11...
# 1   415601764128268  [BÀI CHIA SẺ CẢM NHẬN]\nNAPer 2K6: Nguyễn Thị ...
# 2   415420370813074  🔥 BÁO ĐIỂM VINH DANH 🔥\nKIỂM TRA ĐỊNH KỲ - 2K6...
# 3   415403874148057  THÔNG BÁO\nDo sự cố mất mạng nên buổi LIVE chữ...
# 4   415367664151678  🔥 THI THỰC CHIẾN CHUYÊN ĐỀ - 2K6 LỚP 12 - LẦN ...
# ..              ...                                                ...
# 95  397097782645333  KẾ HOẠCH HỌC LIVE TUẦN TỚI\nPS. TUẦN SAU 2K7 -...
# 96  396526536035791  Thấy bảo 364 ngày nữa là 20/10/2024 phải không...
# 97  396217742733337       Từ chiều đến giờ mới xong bữa 20/10 các em à
# 98  395553969466381  KHÍ NÀO NỮA CÁC EM NHỈ 😊\n===\nKHÔNG NHANH TAY...
# 99  343564324796564                     YÊU LẠI TỪ ĐẦU - BG: 1.1 + 1.2
#
#                   time   timestamp  \
# 0  2023-11-27 03:06:06  1701054366
# 1  2023-11-27 00:16:07  1701044167
# ...

# %% [markdown]
# # Phân tích sự phát triển của react qua các bài post

# %%
df_reactions[['time','reaction_count']]
# Out:
#                   time  reaction_count
# 0  2023-11-27 03:06:06              61
# 1  2023-11-27 00:16:07             186
# 2  2023-11-26 15:05:55             266
# 3  2023-11-26 14:27:45             256
# 4  2023-11-26 13:00:26             386
# ..                 ...             ...
# 95 2023-10-22 01:17:26             428
# 96 2023-10-21 03:00:43            1123
# 97 2023-10-20 12:32:24             925
# 98 2023-10-19 06:41:42             764
# 99 2023-10-17 12:46:22            1029
#
# [100 rows x 2 columns]

# %%
# số lượt react qua các post
x = df_reactions[['thích', 'yêu thích', 'thương thương','haha', 'wow', 'buồn', 'phẫn nộ']]
ax = x.plot(kind='bar', figsize=(20,8), stacked=True)
ax.set_xlabel('Post')
ax.set_ylabel('Lượng reactions')
# Out:
# Text(0, 0.5, 'Lượng reactions')

# %%
# Biến động của tổng react qua các post
ax=df_reactions['reaction_count'].plot(kind = 'line', figsize=(20,8))
ax.set_xlabel('post')
ax.set_ylabel('Tổng reactions')
# Out:
# Text(0, 0.5, 'Tổng reactions')

# %%
# tổng lượng reactions của 100 post
df_reactions['reaction_count'].sum()
# Out:
# 63541

# %%
# lượng reactions trung bình của mỗi post
df_reactions['reaction_count'].mean()
# Out:
# 635.41

# %%
df_reactions['reaction_count'].median()
# Out:
# 502.0

# %%
likes = df_reactions['thích'].sum()
loves = df_reactions['yêu thích'].sum()
hahas = df_reactions['haha'].sum()
thuongthuongs = df_reactions['thương thương'].sum()
wows = df_reactions['wow'].sum()
buons = df_reactions['buồn'].sum()
phannos = df_reactions['phẫn nộ'].sum()
plt.pie([likes, loves,hahas, thuongthuongs, wows, buons, phannos], labels=["Like","Yêu thích", "Haha", "Thương thương", "Wow", "Buồn", "Phẫn nộ"],
        colors=["red", "pink","yellow", "green", "blue", "orange", "purple"], textprops={'size': 'smaller'}, radius=1.5)
plt.show()

# %% [markdown]
# # Phân tích từng loại react theo thời gian

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot(df_reactions['time'], df_reactions['thích'], label = "Thích", marker="o")
ax.plot(df_reactions['time'], df_reactions['yêu thích'], label = "Yêu thích", marker="o")
ax.plot(df_reactions['time'], df_reactions['thương thương'], label = "Thương thương", marker="o")
ax.plot(df_reactions['time'], df_reactions['haha'], label = "Haha", marker="o")
ax.plot(df_reactions['time'], df_reactions['wow'], label = "Wow", marker="o")
ax.plot(df_reactions['time'], df_reactions['buồn'], label = "Buồn", marker="o")
ax.plot(df_reactions['time'], df_reactions['phẫn nộ'], label = "Phẫn nộ", marker="o")
ax.plot(df_reactions['time'], df_reactions['shares'], label = "Shares", marker="s")
ax.plot(df_reactions['time'], df_reactions['comments'], label = "Comments", marker="*")
ax.plot(df_reactions['time'], df_reactions['reaction_count'], label = "reaction_count", marker="*")
ax.set_xlabel('time')
ax.set_ylabel('reaction count')

plt.legend()
from matplotlib.dates import DateFormatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%y %H:%M'))
