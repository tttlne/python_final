# %% [markdown]
# <a href="https://colab.research.google.com/github/tttlne/python_final/blob/master/Crawl_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Facebook Data Crawling
# In this notebook, we will be crawling data from Facebook using the Facebook Graph API. We will be using the facebook-scraper

# %% [markdown]
# ## Install the required library
# We will be using the facebook-scraper library to crawl data from Facebook. We will install this library using pip.

# %%
# %pip install facebook_scraper pandas numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from facebook_scraper import get_posts
import pandas as pd
import numpy as np

# %%
FANPAGE_LINK ="napbook.vn"
FOLDER_PATH = "/content/drive/MyDrive/Colab_Notebooks/"
COOKIE_PATH = "/content/drive/MyDrive/Colab_Notebooks/cookies.txt"

PAGES_NUMBER =  10 # Number of pages to crawl

# %%
post_list = []
for post in get_posts(FANPAGE_LINK,
                    options={"comments": True, "reactions": True, "allow_extra_requests": True},
                    extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH):
    print(post)
    post_list.append(post)

# %% [markdown]
# ## Convert list of dicts to df

# %%
post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)

# %%
path=FOLDER_PATH + FANPAGE_LINK + ".xlsx"
post_df_full.to_excel(FOLDER_PATH + FANPAGE_LINK + ".xlsx", index=False)
print(path)
# Out:
# /content/drive/MyDrive/Colab_Notebooks/napbook.vn.xlsx

# %%
arr = np.array(post_list)
path1=FOLDER_PATH + FANPAGE_LINK + ".npy"
np.save(path1, arr)

# %%
post_list = pd.read_excel("/content/drive/MyDrive/Colab_Notebooks/napbook.vn.xlsx")

# %%
post_list.head(5)
# Out:
#            post_id                                               text  \
# 0  415655727456205  VIDEO: CHỮA ĐỀ THỰC CHIẾN - LẦN 18 [CN - 26/11...
# 1  415601764128268  [BÀI CHIA SẺ CẢM NHẬN]\nNAPer 2K6: Nguyễn Thị ...
# 2  415420370813074  🔥 BÁO ĐIỂM VINH DANH 🔥\nKIỂM TRA ĐỊNH KỲ - 2K6...
# 3  415403874148057  THÔNG BÁO\nDo sự cố mất mạng nên buổi LIVE chữ...
# 4  415367664151678  🔥 THI THỰC CHIẾN CHUYÊN ĐỀ - 2K6 LỚP 12 - LẦN ...
#
#                                            post_text shared_text  \
# 0  VIDEO: CHỮA ĐỀ THỰC CHIẾN - LẦN 18 [CN - 26/11...         NaN
# 1  [BÀI CHIA SẺ CẢM NHẬN]\nNAPer 2K6: Nguyễn Thị ...         NaN
# 2  🔥 BÁO ĐIỂM VINH DANH 🔥\nKIỂM TRA ĐỊNH KỲ - 2K6...         NaN
# 3  THÔNG BÁO\nDo sự cố mất mạng nên buổi LIVE chữ...         NaN
# 4  🔥 THI THỰC CHIẾN CHUYÊN ĐỀ - 2K6 LỚP 12 - LẦN ...         NaN
#
#    original_text                 time     timestamp  \
# 0            NaN  2023-11-27 03:06:06  1.701054e+09
# ...

# %%
list_url_miss = [
'https://facebook.com/napbook.vn/posts/401085175579927',
'https://facebook.com/napbook.vn/posts/401023328919445',
'https://facebook.com/napbook.vn/posts/400413612313750',
'https://facebook.com/napbook.vn/posts/399881115700333',
'https://facebook.com/napbook.vn/posts/1020047485944909',
'https://facebook.com/napbook.vn/posts/399157715772673',
'https://facebook.com/napbook.vn/posts/398777829143995',
'https://facebook.com/napbook.vn/posts/860389435406590',
'https://facebook.com/napbook.vn/posts/398467809174997',
'https://facebook.com/napbook.vn/posts/303576072622213',
'https://facebook.com/napbook.vn/posts/347199761011558',
'https://facebook.com/napbook.vn/posts/397237752631336',
'https://facebook.com/napbook.vn/posts/397144845973960',
'https://facebook.com/napbook.vn/posts/397097782645333',
'https://facebook.com/napbook.vn/posts/396526536035791',
'https://facebook.com/napbook.vn/posts/396217742733337',
'https://facebook.com/napbook.vn/posts/395553969466381',
'https://facebook.com/napbook.vn/posts/343564324796564']

# %%
from facebook_scraper import get_posts
for i in range(len(list_url_miss)):
  post = next(get_posts(post_urls=[list_url_miss[i]], options={"comments": True, "reactions": True}))
  post_list.append(post)
# Out:
# WARNING:facebook_scraper.extractors:[pfbid02mAtsBFvmzVaMaEipQqkjPD9DHiezdB9ZPcJ5zWLHfZcYSwLFtckPxo9Rr19Sq7GJl] Extract method extract_video didn't return anything
# WARNING:facebook_scraper.extractors:[pfbid02mAtsBFvmzVaMaEipQqkjPD9DHiezdB9ZPcJ5zWLHfZcYSwLFtckPxo9Rr19Sq7GJl] Extract method extract_video_thumbnail didn't return anything
# WARNING:facebook_scraper.extractors:[pfbid02mAtsBFvmzVaMaEipQqkjPD9DHiezdB9ZPcJ5zWLHfZcYSwLFtckPxo9Rr19Sq7GJl] Extract method extract_video_id didn't return anything
# WARNING:facebook_scraper.extractors:[pfbid02mAtsBFvmzVaMaEipQqkjPD9DHiezdB9ZPcJ5zWLHfZcYSwLFtckPxo9Rr19Sq7GJl] Extract method extract_video_meta didn't return anything
# WARNING:facebook_scraper.extractors:[pfbid02mAtsBFvmzVaMaEipQqkjPD9DHiezdB9ZPcJ5zWLHfZcYSwLFtckPxo9Rr19Sq7GJl] Extract method extract_factcheck didn't return anything
# ...

# %%
post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)

# %%
path=FOLDER_PATH + FANPAGE_LINK + ".xlsx"
post_df_full.to_excel(FOLDER_PATH + FANPAGE_LINK + ".xlsx", index=False)
print(path)
# Out:
# /content/drive/MyDrive/Colab_Notebooks/napbook.vn.xlsx
